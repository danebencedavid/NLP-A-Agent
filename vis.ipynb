# %% [markdown]
# <a href="https://colab.research.google.com/github/danebencedavid/NLP-A-Agent/blob/master/vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
embeddings = np.load("/content/drive/MyDrive/full_abs_embeddings/embeddings_batch_0.npy")

print("Embeddings shape:", embeddings.shape)
# Out:
# Embeddings shape: (35, 768)

# %%
np.savetxt(
    "/content/drive/MyDrive/embedding_projector/vectors.tsv",
    embeddings,
    delimiter="\t",
    fmt="%.6f"
)

# %%
metadata = pd.read_csv('/content/drive/MyDrive/fulldf_papers.csv')

# %%
metadata['abstract'] = metadata['abstract'].fillna('')
non_empty_df = metadata[metadata['abstract'].str.strip() != ''].copy()
metadata = non_empty_df

# %%
len(metadata)
# Out:
# 35

# %%
metadata.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id', 'smoking_score', 'covid_score', 'combined_score',
#        'diabetes_score'],
#       dtype='object')

# %%
metadata = metadata[['title','doi','smoking_score', 'covid_score',
       'diabetes_score']].copy()

# %%
metadata.to_csv(
    "/content/drive/MyDrive/embedding_projector/metadata.tsv",
    sep="\t",
    index=False
)

# %%
# !head -n 3 "/content/drive/MyDrive/embedding_projector/vectors.tsv"
# !head -n 3 "/content/drive/MyDrive/embedding_projector/metadata.tsv"
# Out:
# 0.175123	0.450797	0.007402	0.755791	0.574148	-0.249612	0.205456	-0.629092	0.914989	-0.521196	-0.383336	0.205753	-0.497120	0.208823	-0.384127	-0.018224	0.216185	0.123918	0.236479	-0.203120	-0.423045	-0.060174	0.006820	-0.361430	-0.583676	-0.200422	0.358661	-0.196738	-0.371246	0.064204	-0.520956	0.163776	-0.585253	0.445738	-0.084822	0.034597	0.004570	-0.191302	0.072588	-0.136219	-0.306202	0.021271	-0.215830	0.369047	-0.577092	0.097966	-0.139463	-0.403459	-0.394727	-0.129315	-0.267793	0.444522	0.334298	-0.227025	0.358664	0.301911	-0.027885	-0.274456	-0.093756	-0.074585	-0.276518	-0.127548	0.103846	0.278912	0.554720	-0.013982	-0.425158	0.009247	-0.166146	0.689260	0.210906	0.017294	0.165151	-0.314489	0.359786	-0.078941	-0.231346	-0.625056	0.017661	-0.189016	0.274916	0.389580	-0.162379	0.791152	-0.347933	-0.039217	0.502105	-0.224313	-0.620728	0.035382	-0.350826	0.169400	-0.157101	0.269585	0.935478	0.494044	0.135855	-0.099197	-0.567657	-0.352632	0.171415	0.335327	-0.221702	0.344599	0.448970
# ...
